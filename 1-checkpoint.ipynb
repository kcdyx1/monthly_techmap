# %% [markdown]
# # 8月全球科技热点统计报告
# 数据来源：全球技术地图
#
# ----

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import imageio
from wordcloud import WordCloud
import jieba
import jieba.analyse

jieba.analyse.set_idf_path("./dicts/idf.txt")

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

d = pd.read_csv('./1808/8yue_all.csv',sep='|',header=0)

d.describe()
# Out:
#                 title                                            content  \
# count             352                                                352
# unique            352                                                352
# top     印度核电2017年成果显著  据Technology.org网站8月23日消息，华盛顿大学圣路易斯工程与应用科学学院利用细...
# freq                1                                                  1
#
#        field       source   date  \
# count    352          352    352
# unique     9          134     32
# top       信息  EurekAlert网  8月13日
# freq      70           29     21
#
#                                             content_clean
# count                                                 352
# unique                                                352
# top     美国独立咨询公司高德纳（GartnerGroup）发布人工智能技术成熟度曲线，追踪人工智能创...
# freq                                                    1

# %%
field_stat = pd.DataFrame(d['field'].value_counts())
field_stat
# Out:
#       field
# 信息       70
# 生物       63
# 能源       52
# 科技战略     39
# 新材料      30
# 航空       28
# 海洋       25
# 航天       24
# 先进制造     21

# %%
plt.rcParams['font.family'] = ['Source Han Sans CN']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

field_stat.plot(kind = 'bar', colormap='tab20')
plt.xlabel('领域')
plt.ylabel('热点事件数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
field_stat['proportion'] = field_stat['field'].map(lambda x: x/352)
field_stat
field_stat.plot(y='proportion',kind = 'pie',legend=False,figsize=(5,5),colormap='Set3')
# plt.xlabel('领域')
# plt.ylabel('热点事件数量')
# plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
source_stat = pd.DataFrame(d['source'].value_counts())
source_stat[0:20].plot(kind = 'bar')
plt.xlabel('信息源')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
date_stat = pd.DataFrame(d['date'].value_counts())
date_stat.plot(kind = 'bar')
plt.xlabel('日期')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %% [markdown]
# ## 1. 信息领域
#
# -------

# %%
xx = d[d.field == '信息']
xx.describe()
# Out:
#                title                                            content field  \
# count             70                                                 70    70
# unique            70                                                 70     1
# top     巴西总统签署数据保护法案  据路透社8月21日消息，微软公司在周二发布的一份报告中表示，与俄罗斯政府有关的黑客试图对美国...    信息
# freq               1                                                  1    70
#
#              source  date                                      content_clean
# count            70    70                                                 70
# unique           34    24                                                 70
# top     EurekAlert网  8月7日  为加速开发可实用的量子计算机，美国国家科学基金会（NSF）启动软件定制架构的量子协同设计项目...
# freq             13     7                                                  1

# %%
source_stat = pd.DataFrame(xx['source'].value_counts())
source_stat[0:10].plot(kind = 'bar')
plt.xlabel('信息源')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
date_stat = pd.DataFrame(xx['date'].value_counts())
date_stat[:10].plot(kind = 'bar')
plt.xlabel('日期')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
keywords_list = []
for i in xx['content_clean']:
    tags = jieba.analyse.extract_tags(i, topK=10, withWeight=False, allowPOS=('n','nr','ns','nz','nt'))
    for j in tags:
        keywords_list.append(j)
        
wclist = " ".join(keywords_list)
# print(wclist)
# def wordcount(wl):
#     # 文章字符串前期处理
#     count_dict = {}
#     # 如果字典里有该单词则加1，否则添加入字典
#     for str in wl:
#         if str in count_dict.keys():
#             count_dict[str] = count_dict[str] + 1
#         else:
#             count_dict[str] = 1
#     count_list=sorted(count_dict.items(),key=lambda x:x[1],reverse=True)
#     return count_list

# print(wordcount(keywords_list)[0:50])


# bg_pic = imageio.imread('./bg.jpeg')
wc = WordCloud(
    colormap='tab20c',
    background_color="white", #背景颜色
    font_path= "./font/syht.otf",  #字体用思源黑体
    max_words=100, #显示最大词数
    min_font_size=30,
    max_font_size=150, 
    width=1200,  #图幅宽度
    height=800   #词云高度
    )
wc.generate(wclist)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('./1.png')
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/m7/7lm92hx92zb89939mng3l23c0000gn/T/jieba.cache
# Loading model cost 0.986 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# ## 2. 生物领域
#
# ------

# %%
sw = d[d.field == '生物']
sw.describe()
# Out:
#                                   title  \
# count                                63
# unique                               63
# top     美科学家开发新型氘代谢成像技术，通过监控体内物质代谢以揭示药效
# freq                                  1
#
#                                                   content field source   date  \
# count                                                  63    63     63     63
# unique                                                 63     1     28     26
# top     据生物谷网8月26日消息，美国耶鲁大学等单位研究人员开发出一种氘代谢成像技术（DMI），即利...    生物   生物谷网  8月14日
# freq                                                    1    63     10      5
#
#                                             content_clean
# count                                                  63
# unique                                                 63
# top     美国国立卫生研究院国家过敏和传染病研究所（NIAID）科学家开发的实验性减毒寨卡病毒疫苗已开...
# freq                                                    1

# %%
source_stat = pd.DataFrame(sw['source'].value_counts())
source_stat[0:10].plot(kind = 'bar')
plt.xlabel('信息源')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
date_stat = pd.DataFrame(sw['date'].value_counts())
date_stat.plot(kind = 'bar')
plt.xlabel('日期')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
keywords_list = []
for i in sw['content_clean']:
    tags = jieba.analyse.extract_tags(i, topK=10, withWeight=False, allowPOS=('n','nr','ns','nz','nt'))
    for j in tags:
        keywords_list.append(j)
        
wclist = " ".join(keywords_list)
# print(wclist)
# def wordcount(wl):
#     # 文章字符串前期处理
#     count_dict = {}
#     # 如果字典里有该单词则加1，否则添加入字典
#     for str in wl:
#         if str in count_dict.keys():
#             count_dict[str] = count_dict[str] + 1
#         else:
#             count_dict[str] = 1
#     count_list=sorted(count_dict.items(),key=lambda x:x[1],reverse=True)
#     return count_list

# print(wordcount(keywords_list)[0:50])


# bg_pic = imageio.imread('./bg.jpeg')
wc = WordCloud(
    colormap='tab20c',
    background_color="white", #背景颜色
    font_path= "./font/syht.otf",  #字体用思源黑体
    max_words=100, #显示最大词数
    min_font_size=30,
    max_font_size=150, 
    width=1200,  #图幅宽度
    height=800   #词云高度
    )
wc.generate(wclist)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('./2.png')

# %% [markdown]
# ## 3. 能源领域
#
# -------

# %%
ny = d[d.field == '能源']
ny.describe()
# Out:
#                 title                                            content  \
# count              52                                                 52
# unique             52                                                 52
# top     印度核电2017年成果显著  据北极星风力发电网8月15日消息，日本电源开发公司、政府投资银行和关西电力公司将获得德国知名...
# freq                1                                                  1
#
#        field   source   date  \
# count     52       52     52
# unique     1       19     23
# top       能源  国防科技信息网  8月29日
# freq      52       12      6
#
#                                             content_clean
# count                                                  52
# unique                                                 52
# top     日本“CHAdeMO”协议会和中国推广“GB/T”标准的“中国电力企业联合会”签署联合制定新...
# freq                                                    1

# %%
source_stat = pd.DataFrame(ny['source'].value_counts())
source_stat[0:15].plot(kind = 'bar')
plt.xlabel('信息源')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
date_stat = pd.DataFrame(ny['date'].value_counts())
date_stat.plot(kind = 'bar')
plt.xlabel('日期')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
keywords_list = []
for i in ny['content_clean']:
    tags = jieba.analyse.extract_tags(i, topK=10, withWeight=False, allowPOS=('n','nr','ns','nz','nt'))
    for j in tags:
        keywords_list.append(j)
        
wclist = " ".join(keywords_list)

wc = WordCloud(
    colormap='tab20c',
    background_color="white", #背景颜色
    font_path= "./font/syht.otf",  #字体用思源黑体
    max_words=100, #显示最大词数
    min_font_size=30,
    max_font_size=150, 
    width=1200,  #图幅宽度
    height=800   #词云高度
    )
wc.generate(wclist)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('./3.png')

# %% [markdown]
# ## 4. 科技战略
#
# ----------

# %%
kj = d[d.field == '科技战略']
kj.describe()
# Out:
#                                    title  \
# count                                 39
# unique                                39
# top     美国发布《2013-2022年行星科学的愿景与旅程》中期审查报告
# freq                                   1
#
#                                                   content field   source  \
# count                                                  39    39       39
# unique                                                 39     1       22
# top     据国防科技要闻8月17日消息，美国《防务新闻》周刊发布2018版军工百强企业排行榜。2017...  科技战略  国防科技信息网
# freq                                                    1    39        5
#
#         date                                      content_clean
# count     39                                                 39
# unique    22                                                 39
# top     8月2日  英国国防部国防和安全加速器（DASA，2016年新成立的部门）启动“预测性网络分析”竞赛，寻...
# freq       6                                                  1

# %%
source_stat = pd.DataFrame(kj['source'].value_counts())
source_stat[0:15].plot(kind = 'bar')
plt.xlabel('信息源')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
date_stat = pd.DataFrame(kj['date'].value_counts())
date_stat.plot(kind = 'bar')
plt.xlabel('日期')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
keywords_list = []
for i in kj['content_clean']:
    tags = jieba.analyse.extract_tags(i, topK=10, withWeight=False, allowPOS=('n','nr','ns','nz','nt'))
    for j in tags:
        keywords_list.append(j)
        
wclist = " ".join(keywords_list)

wc = WordCloud(
    colormap='tab20c',
    background_color="white", #背景颜色
    font_path= "./font/syht.otf",  #字体用思源黑体
    max_words=100, #显示最大词数
    min_font_size=30,
    max_font_size=150, 
    width=1200,  #图幅宽度
    height=800   #词云高度
    )
wc.generate(wclist)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('./4.png')

# %% [markdown]
# ## 5. 新材料领域
#
# ------

# %%
cl = d[d.field == '新材料']
cl.describe()
# Out:
#                                 title  \
# count                              30
# unique                             30
# top     滑铁卢大学锂-氧电池研究取得新突破，可将理论储能提高50%
# freq                                1
#
#                                                   content field       source  \
# count                                                  30    30           30
# unique                                                 30     1            9
# top     据Technology.org网站8月23日消息，华盛顿大学圣路易斯工程与应用科学学院利用细...   新材料  EurekAlert网
# freq                                                    1    30           12
#
#          date                                      content_clean
# count      30                                                 30
# unique     17                                                 30
# top     8月28日  哈佛大学研究人员开发出基于声波的“万能”打印技术，可用于打印之前无法打印的液体。喷墨打印是最...
# freq        4                                                  1

# %%
source_stat = pd.DataFrame(cl['source'].value_counts())
source_stat[0:15].plot(kind = 'bar')
plt.xlabel('信息源')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
date_stat = pd.DataFrame(cl['date'].value_counts())
date_stat.plot(kind = 'bar')
plt.xlabel('日期')
plt.ylabel('采集数量')
plt.title('全球各领域科技热点事件数量统计')
plt.show()

# %%
keywords_list = []
for i in cl['content_clean']:
    tags = jieba.analyse.extract_tags(i, topK=10, withWeight=False, allowPOS=('n','nr','ns','nz','nt'))
    for j in tags:
        keywords_list.append(j)
        
wclist = " ".join(keywords_list)

wc = WordCloud(
    colormap='tab20c',
    background_color="white", #背景颜色
    font_path= "./font/syht.otf",  #字体用思源黑体
    max_words=100, #显示最大词数
    min_font_size=30,
    max_font_size=150, 
    width=1200,  #图幅宽度
    height=800   #词云高度
    )
wc.generate(wclist)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('./4.png')
